# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Start DataScience

# %%
data_path = r"C:\Users\Afina\projects\Job-parser-for-work.ua\data\IT_KYIV_306.xlsx"

# %%
df = pd.read_excel(data_path)

# %%
df.describe()
# Out:
#           min salary     max salary    ai score
# count      89.000000      89.000000  306.000000
# mean    31067.415730   61702.247191   12.336601
# std     16280.375633   38696.120834    1.809202
# min      5000.000000    8000.000000    8.000000
# 25%     23000.000000   32000.000000   12.000000
# 50%     27000.000000   50000.000000   12.000000
# 75%     35000.000000   80000.000000   12.000000
# max    124000.000000  186000.000000   15.000000

# %% [markdown]
# Отримання всіх ваканцій з оцінкою більше 15

# %%
top_jobs = df[df["ai score"] >= 15]
top_jobs.head()
# Out:
#                       position  min salary  max salary           company  \
# 0           Embedded-розробник     80000.0    120000.0          Optronix
# 1  Програміст мікроконтролерів     60000.0    120000.0  Handrex Mobility
# 2              Разработчик PHP     50000.0     80000.0   Avala solutions
# 3     Електронщик, схемотехнік     50000.0     80000.0  Handrex Mobility
# 4          Front-end developer     40000.0     60000.0        Concept 44
#
#                          class  \
# 0     IT; 10–50 співробітників
# 1  IT; менше 10 співробітників
# 2     IT; 10–50 співробітників
# 3  IT; менше 10 співробітників
# 4  IT; менше 10 співробітників
#
#                                         requirements  \
# 0       Повна зайнятість. Досвід роботи від 2 років.
# 1  Повна зайнятість. Також готові взяти студента,...
# 2  Повна зайнятість, неповна зайнятість. Також го...
# 3  Повна зайнятість. Також готові взяти студента,...
# 4        Повна зайнятість. Досвід роботи від 1 року.
#
#                                               skills    verify  \
# 0  Користувач ОС Linux, C++, TCP/IP, Програмуванн...  verified
# 1  Користувач ОС Windows, MATLAB, Програмування, ...  verified
# 2  Ведення CRM, JavaScript, Python, PostgreSQL, R...  verified
# 3  Знання САПР, Altium Designer, Складання електр...  verified
# 4  CSS, Figma, JavaScript, HTML, Git, React, Type...  verified
#
#                                   url  ai score
# 0  https://www.work.ua//jobs/6915031/        15
# 1  https://www.work.ua//jobs/5113676/        15
# 2  https://www.work.ua//jobs/6839389/        15
# 3  https://www.work.ua//jobs/5182632/        15
# 4  https://www.work.ua//jobs/6873055/        15

# %%
data_science_mask = (df["class"] == "IT; 10–50 співробітників") & (df["ai score"] > 13)
data_science = df[data_science_mask]
data_science.head()
# Out:
#                    position  min salary  max salary          company  \
# 0        Embedded-розробник     80000.0    120000.0         Optronix
# 2           Разработчик PHP     50000.0     80000.0  Avala solutions
# 5        Sales manager (ІТ)     40000.0     60000.0        Neuroshop
# 8  Junior Shopify Developer     30000.0     60000.0      Base X Tech
# 9          Python Developer     30000.0     50000.0         Devprove
#
#                       class  \
# 0  IT; 10–50 співробітників
# 2  IT; 10–50 співробітників
# 5  IT; 10–50 співробітників
# 8  IT; 10–50 співробітників
# 9  IT; 10–50 співробітників
#
#                                         requirements  \
# 0       Повна зайнятість. Досвід роботи від 2 років.
# 2  Повна зайнятість, неповна зайнятість. Також го...
# 5  Повна зайнятість, неповна зайнятість. Досвід р...
# 8  Повна зайнятість. Також готові взяти студента....
# 9  Повна зайнятість, неповна зайнятість. Досвід р...
#
#                                               skills    verify  \
# 0  Користувач ОС Linux, C++, TCP/IP, Програмуванн...  verified
# 2  Ведення CRM, JavaScript, Python, PostgreSQL, R...  verified
# 5  Користувач ПК, Знання офісних програм, Комунік...       NaN
# 8  Розробка сайтів на Shopify, Tailwind CSS, Java...       NaN
# 9                                             Python  verified
#
#                                   url  ai score
# 0  https://www.work.ua//jobs/6915031/        15
# 2  https://www.work.ua//jobs/6839389/        15
# 5  https://www.work.ua//jobs/6112147/        15
# 8  https://www.work.ua//jobs/6473113/        15
# 9  https://www.work.ua//jobs/5352823/        15

# %%
data_science.sort_values(by="ai score", ascending=True)
# Out:
#                                              position  min salary  max salary  \
# 0                                  Embedded-розробник     80000.0    120000.0
# 2                                     Разработчик PHP     50000.0     80000.0
# 5                                  Sales manager (ІТ)     40000.0     60000.0
# 8                            Junior Shopify Developer     30000.0     60000.0
# 9                                    Python Developer     30000.0     50000.0
# 12                                    Project manager     28000.0     32000.0
# 13                                Junior Data Analyst     27000.0     32000.0
# 16               Збиральник серверів (ПК, комп'ютери)     26000.0     30000.0
# 18                               Project Manager (IT)     25000.0     40000.0
# 19                      Інженер з ремонту електроніки     25000.0     30000.0
# 21       Спеціаліст технічної підтримки в IT-компанію     20000.0     25000.0
# 22                            Системний адміністратор     20000.0     25000.0
# 25  Помічник системного адміністратора (ст. м. Бор...     18000.0     20000.0
# 26                                    Тестувальник ПО     15000.0     25000.0
# 27  Інженер зі збірки електронних пристроїв в IT-к...         NaN         NaN
# 44                                      Web Developer         NaN         NaN
# 47   Junior project manager (business team, AI сфера)         NaN         NaN
# 48  Технік, сервісний інженер, електронщик з власн...         NaN         NaN
# 51                          Інженер-програміст АСК ТП         NaN         NaN
# 58                      Head of sales (B2B, AI-сфера)         NaN         NaN
# 59  Експерт-аналітик з управління комунальними вит...         NaN         NaN
# 61  Full-stack Developer (PHP, HTML, CSS, jQuery P...         NaN         NaN
# 63                                 Manual QA Engineer         NaN         NaN
# 68         Менеджер з підтримки продажів ІТ-продуктів         NaN         NaN
#
#                    company                     class  \
# 0                 Optronix  IT; 10–50 співробітників
# 2          Avala solutions  IT; 10–50 співробітників
# 5                Neuroshop  IT; 10–50 співробітників
# 8              Base X Tech  IT; 10–50 співробітників
# 9                 Devprove  IT; 10–50 співробітників
# 12    Мироненко Б. В., ФОП  IT; 10–50 співробітників
# 13       Поліщук Д.В., ФОП  IT; 10–50 співробітників
# 16     Onix Solutions, LLC  IT; 10–50 співробітників
# 18                    Мемо  IT; 10–50 співробітників
# 19            Vending Land  IT; 10–50 співробітників
# 21               ProstoPay  IT; 10–50 співробітників
# 22  Октопус Кібер Сервісес  IT; 10–50 співробітників
# 25        Алегрос ЛТД, ООО  IT; 10–50 співробітників
# 26                 Укр.Пей  IT; 10–50 співробітників
# 27               ProstoPay  IT; 10–50 співробітників
# 44                 Укр.Пей  IT; 10–50 співробітників
# 47              Artellence  IT; 10–50 співробітників
# 48               Neuroshop  IT; 10–50 співробітників
# 51       Скиф-Контрол, ООО  IT; 10–50 співробітників
# 58              Artellence  IT; 10–50 співробітників
# 59            Lead Team IT  IT; 10–50 співробітників
# 61                Devprove  IT; 10–50 співробітників
# 63  ЛІС, ТОВ (IT-компанія)  IT; 10–50 співробітників
# 68                   Amind  IT; 10–50 співробітників
#
#                                          requirements  \
# 0        Повна зайнятість. Досвід роботи від 2 років.
# 2   Повна зайнятість, неповна зайнятість. Також го...
# 5   Повна зайнятість, неповна зайнятість. Досвід р...
# 8   Повна зайнятість. Також готові взяти студента....
# 9   Повна зайнятість, неповна зайнятість. Досвід р...
# 12                                  Повна зайнятість.
# 13                                  Повна зайнятість.
# 16        Повна зайнятість. Досвід роботи від 1 року.
# 18        Повна зайнятість. Досвід роботи від 1 року.
# 19  Повна зайнятість. Також готові взяти студента,...
# 21  Повна зайнятість. Також готові взяти студента,...
# 22  Повна зайнятість. Також готові взяти студента....
# 25  Повна зайнятість. Також готові взяти студента....
# 26  Повна зайнятість. Досвід роботи від 1 року. Ви...
# 27  Повна зайнятість. Також готові взяти студента,...
# 44  Повна зайнятість. Досвід роботи від 2 років. В...
# 47  Повна зайнятість. Також готові взяти студента....
# 48       Повна зайнятість. Досвід роботи від 2 років.
# 51  Повна зайнятість. Також готові взяти студента,...
# 58  Повна зайнятість. Досвід роботи від 5 років. В...
# 59       Повна зайнятість. Досвід роботи від 2 років.
# 61  Повна зайнятість, неповна зайнятість. Досвід р...
# 63  Повна зайнятість. Досвід роботи від 2 років. В...
# 68  Повна зайнятість. Також готові взяти студента....
#
#                                                skills    verify  \
# 0   Користувач ОС Linux, C++, TCP/IP, Програмуванн...  verified
# 2   Ведення CRM, JavaScript, Python, PostgreSQL, R...  verified
# 5   Користувач ПК, Знання офісних програм, Комунік...       NaN
# 8   Розробка сайтів на Shopify, Tailwind CSS, Java...       NaN
# 9                                              Python  verified
# 12  Jira, Trello, Організованість, Копірайтинг, Ма...       NaN
# 13  MS Excel, Ведення CRM, SQL, Google Analytics, ...       NaN
# 16  Уважність, Акуратність, Охайність, Неконфліктн...  verified
# 18  Комунікабельність, Стресостійкість, Управління...  verified
# 19  Водійські права кат. B, Відповідальність, Поря...  verified
# 21  Здатність до навчання, Грамотна усна та письмо...  verified
# 22  Користувач ОС Windows, Технічна підтримка кори...  verified
# 25                   Користувач ОС Windows, Ремонт ПК  verified
# 26  SQL, Відповідальність, Postman, Робота в коман...  verified
# 27                   Уважність, Висока працездатність  verified
# 44  CSS, JavaScript, HTML, Git, React, jQuery, Red...  verified
# 47                                                NaN  verified
# 48  Користувач ОС Linux, Користувач ОС Windows, Зб...       NaN
# 51                                 C++, Програмування  verified
# 58                                                NaN  verified
# 59  MS Excel, SQL, Google Sheets, Looker Studio, А...  verified
# 61  CSS, JavaScript, HTML, PHP, MySQL, Git, React,...  verified
# 63  CSS, HTML, HTTP, Верстка, Дизайн, Робота з баз...  verified
# 68  MS Office, Контроль документообігу, Уважність,...  verified
#
#                                    url  ai score
# 0   https://www.work.ua//jobs/6915031/        15
# 2   https://www.work.ua//jobs/6839389/        15
# 5   https://www.work.ua//jobs/6112147/        15
# 8   https://www.work.ua//jobs/6473113/        15
# 9   https://www.work.ua//jobs/5352823/        15
# 12  https://www.work.ua//jobs/6976348/        15
# 13  https://www.work.ua//jobs/6935170/        15
# 16  https://www.work.ua//jobs/6713137/        15
# 18  https://www.work.ua//jobs/5858645/        15
# 19  https://www.work.ua//jobs/5490441/        15
# 21  https://www.work.ua//jobs/6068988/        15
# 22  https://www.work.ua//jobs/6932635/        15
# 25  https://www.work.ua//jobs/5877357/        15
# 26  https://www.work.ua//jobs/2924376/        15
# 27  https://www.work.ua//jobs/5872039/        15
# 44  https://www.work.ua//jobs/6912607/        15
# 47  https://www.work.ua//jobs/6961324/        15
# 48  https://www.work.ua//jobs/6704563/        15
# 51  https://www.work.ua//jobs/5903144/        15
# 58  https://www.work.ua//jobs/6951787/        15
# 59  https://www.work.ua//jobs/6940525/        15
# 61  https://www.work.ua//jobs/6157948/        15
# 63  https://www.work.ua//jobs/6914530/        15
# 68  https://www.work.ua//jobs/5711618/        15
